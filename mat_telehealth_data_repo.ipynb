# %% [markdown]
# # <p style="color:hotpink"> **Maternal Telehealth Synthetic Data Project**
#
# <p style="color:pink">This notebook generates a realistic dataset of maternal telehealth visits, including patient demographics, insurance, visit types, and communication patterns.
#
# <p style="color:pink">It simulates operational outcomes (Show, No-Show, Cancelled, Scheduled) plus patient messages with labeled intent and stress to reflect real-world telehealth operations.
#
# ---

# %% [markdown]
# ## <p style="color:hotpink"> **Data Simulation**
#
# <p style="color:pink">First, simulate 10,000 maternal telehealth appointments with realistic mixes of:
#
# - Insurance types (Medicaid, Major Insurance, Self Pay)
# - Referral sources
# - Visit types (Prenatal, Postpartum, Follow-up, Regular care)
# - Past visit patterns and no-shows
#
# <p style="color:pink">This builds our structured dataset foundation.

# %%
# Re-run full setup after code execution environment reset
import pandas as pd
import numpy as np
import random
from faker import Faker

fake = Faker()
Faker.seed(42)
N = 10000  # Number of fake patients

# Distributions
insurance_mix = {
    "Employer Insured": 0.02,
    "Major Insurance": 0.85,
    "Medicaid": 0.11,
    "Self Pay": 0.02
}

referral_mix = {
    "Provider Referred": 0.50,
    "DME Referred": 0.48,
    "Employer Referred": 0.02,
}

visit_type_mix = {
    "New Patient Postpartum": 0.25,
    "New Patient Prenatal": 0.25,
    "Regular Care": 0.30,
    "Follow-up": 0.20,
}

def simulate_communication(booking_days_prior):
    confirmed = np.random.rand() < 0.75 if booking_days_prior >= 2 else False
    ignored = not confirmed
    return {
        "confirmed_2_days_prior": confirmed,
        "ignored_all_outreach": ignored
    }

def generate_zip():
    return fake.zipcode_in_state(state_abbr=random.choice([
        'CA', 'TX', 'NY', 'FL', 'PA', 'IL', 'OH', 'GA', 'NC', 'MI', 'AZ', 'IN',
        'MO', 'WI', 'CO', 'MN', 'AL', 'SC', 'VA', 'TN', 'MA', 'OK', 'KY', 'LA'
    ]))

# Generate data
data = []
for _ in range(N):
    insurance = random.choices(list(insurance_mix.keys()), weights=insurance_mix.values())[0]
    referral = random.choices(list(referral_mix.keys()), weights=referral_mix.values())[0]
    visit_type = random.choices(list(visit_type_mix.keys()), weights=visit_type_mix.values())[0]
    booking_days_prior = random.randint(0, 30)
    comms = simulate_communication(booking_days_prior)
    past_visits = np.random.randint(0, 6)
    past_no_shows = np.random.choice([0, 1], p=[0.9, 0.1])
    credit_card_on_file = np.random.choice([True, False], p=[0.30, 0.70])
    patient_age = np.random.randint(18, 45)
    baby_age_months = np.random.randint(0, 18) if "Postpartum" in visit_type or "Regular" in visit_type else None

    row = {
        "patient_id": fake.uuid4(),
        "patient_name": fake.name_female(),
        "patient_age": patient_age,
        "zip_code": generate_zip(),
        "insurance": insurance,
        "referral_source": referral,
        "visit_type": visit_type,
        "booking_days_prior": booking_days_prior,
        "confirmed_2_days_prior": comms["confirmed_2_days_prior"],
        "ignored_all_outreach": comms["ignored_all_outreach"],
        "past_visits": past_visits,
        "past_no_shows": past_no_shows,
        "credit_card_on_file": credit_card_on_file,
        "baby_age_months": baby_age_months
    }
    data.append(row)

df = pd.DataFrame(data)

# Assign status
def assign_status(row):
    if row['credit_card_on_file'] or row['confirmed_2_days_prior']:
        return "Show" if np.random.rand() > 0.01 else "Cancelled"
    if row['ignored_all_outreach'] and row['past_visits'] < 3:
        return "No-Show" if np.random.rand() < 0.25 else "Cancelled"
    if row['insurance'] == "Self Pay" and row['booking_days_prior'] > 5:
        return "Cancelled" if np.random.rand() < 0.3 else "Show"
    if row['past_no_shows'] >= 1:
        return "No-Show" if np.random.rand() < 0.15 else "Show"
    return np.random.choice(["Show", "No-Show", "Cancelled"], p=[0.88, 0.07, 0.05])

df["status"] = df.apply(assign_status, axis=1)

df.head(10)
# Out:
#                              patient_id       patient_name  patient_age  \
# 0  bdd640fb-0667-4ad1-9c80-317fa3b1799d     Courtney Doyle           32
# 1  16419f82-8b9d-4434-a465-e150bd9c66b3       Amanda Davis           21
# 2  8fadc1a6-06cb-4fb3-9a1d-e644815ef6d1      Marie Gardner           30
# 3  cf36d58b-4737-4190-96da-1dac72ff5d2a       Olivia Moore           23
# 4  371ecd7b-27cd-4130-8722-9389571aa876    Gabrielle Davis           32
# 5  9a8dca03-580d-4b71-98f5-64135be6128e     Amanda Stevens           19
# 6  142c3fe8-60e7-4113-ac1b-8ca1f91e1d4c  Sandra Montgomery           25
# 7  b45ed1f0-3139-432c-93cd-59bf5c941cf0         Mary Mejia           33
# 8  19db3ad0-ddd1-4fb2-bb98-2ef8daf61a26       Jody Flowers           19
# 9  ab9099a4-35a2-40ae-9af3-05535ec42e08        Taylor Wong           20
#
#   zip_code        insurance    referral_source              visit_type  \
# 0    95544  Major Insurance  Provider Referred  New Patient Postpartum
# 1    55477  Major Insurance  Provider Referred    New Patient Prenatal
# 2    32906  Major Insurance  Provider Referred    New Patient Prenatal
# 3    85866  Major Insurance  Provider Referred    New Patient Prenatal
# 4    70199  Major Insurance       DME Referred            Regular Care
# 5    63512  Major Insurance       DME Referred  New Patient Postpartum
# 6    36768  Major Insurance       DME Referred            Regular Care
# 7    35167  Major Insurance  Provider Referred            Regular Care
# 8    46334  Major Insurance       DME Referred            Regular Care
# 9    86248  Major Insurance  Provider Referred            Regular Care
#
#    booking_days_prior  confirmed_2_days_prior  ignored_all_outreach  \
# 0                   1                   False                  True
# 1                  11                   False                  True
# 2                  17                   False                  True
# 3                   3                    True                 False
# 4                   0                   False                  True
# 5                  18                    True                 False
# 6                  15                    True                 False
# 7                   5                   False                  True
# 8                  12                    True                 False
# 9                  30                    True                 False
#
#    past_visits  past_no_shows  credit_card_on_file  baby_age_months     status
# 0            3              0                False             10.0       Show
# 1            5              0                False              NaN       Show
# 2            2              0                 True              NaN       Show
# 3            0              0                 True              NaN       Show
# 4            2              0                False              8.0  Cancelled
# 5            1              0                 True              9.0       Show
# 6            2              0                False             11.0       Show
# 7            2              0                 True             17.0       Show
# 8            5              0                 True              1.0       Show
# 9            2              0                False              3.0       Show

# %%
df['status'].value_counts()
# Out:
# status
# Show         8779
# Cancelled     897
# No-Show       324
# Name: count, dtype: int64

# %% [markdown]
# ## <p style="color:hotpink"> **Generating Upcoming Appointments**
#
# <p style="color:pink">Next, create 150 upcoming patient appointments that are still in the future, so they have no outcomes yet (status = "Scheduled").
#
# <p style="color:pink">This reflects a realistic operational pipeline, where some appintments have already occurred with known outcomes (show, No-Show, Cancelled), while others are on the books without final attendance data.
#
# <p style="color:pink">These upcoming appointments will later be included in the dataset to simulate an actual telehealth environment with both historical and future visits.

# %%
# Generate 100-200 upcoming appointments (no outcome yet)
N_upcoming = 150
upcoming_data = []

for _ in range(N_upcoming):
    insurance = random.choices(list(insurance_mix.keys()), weights=insurance_mix.values())[0]
    referral = random.choices(list(referral_mix.keys()), weights=referral_mix.values())[0]
    visit_type = random.choices(list(visit_type_mix.keys()), weights=visit_type_mix.values())[0]
    booking_days_prior = random.randint(0, 30)
    comms = simulate_communication(booking_days_prior)
    past_visits = np.random.randint(0, 6)
    past_no_shows = np.random.choice([0, 1], p=[0.9, 0.1])
    credit_card_on_file = np.random.choice([True, False], p=[0.30, 0.70])
    patient_age = np.random.randint(18, 45)
    baby_age_months = np.random.randint(0, 18) if "Postpartum" in visit_type or "Regular Care" in visit_type else None

    row = {
        "patient_id": fake.uuid4(),
        "patient_name": fake.name_female(),
        "patient_age": patient_age,
        "zip_code": generate_zip(),
        "insurance": insurance,
        "referral_source": referral,
        "visit_type": visit_type,
        "booking_days_prior": booking_days_prior,
        "confirmed_2_days_prior": comms["confirmed_2_days_prior"],
        "ignored_all_outreach": comms["ignored_all_outreach"],
        "past_visits": past_visits,
        "past_no_shows": past_no_shows,
        "credit_card_on_file": credit_card_on_file,
        "baby_age_months": baby_age_months,
        "status": "Scheduled" # Outcome not yet known
    }
    upcoming_data.append(row)

df_upcoming = pd.DataFrame(upcoming_data)

# %%
# Combine Upcoming Data to Original Data
df_full = pd.concat([df, df_upcoming], ignore_index=True)

# %%
# Check data is now combined via appt statuses
df_full['status'].value_counts()
# Out:
# status
# Show         8779
# Cancelled     897
# No-Show       324
# Scheduled     150
# Name: count, dtype: int64

# %% [markdown]
# ## <p style="color:hotpink"> **Adding Patient Communication Data**
#
# <p style="color:pink">We sample 500 patients and attach realistic patient messages. Each message is tied to appointment outcome ('status') to reflect real-world patterns.
#
# <p style="color:pink">This creates a combined structured + unstructured dataset.

# %%
# Generate Fake Patient Messages based on appointment status

def generate_message_by_status(status):
    cancel_msgs = [
    ("I can't make it.", "cancel", "medium"),
    ("Cancel.", "cancel", "medium"),
    ("Why was I charged?", "financial_question", "high"),
    ("Is this covered by insurance?", "financial_question", "high"),
    ]
    late_msgs = [
    ("I'm going to be a few minutes late.", "late_notice", "low"),
    ("I'm having trouble joining the link", "late_notice", "high"),
    ]
    reschedule_msgs = [
    ("Can I move my appointment?", "reschedule_request", "medium"),
    ("How do I reschedule?", "reschedule_request", "medium"),
    ("I'm sick, I need to reschedule today.", "reschedule_request", "high"),
    ("RS", "reschedule_request", "low"),
    ("Reschedule", "reschedule_request", "low"),
    ]
    support_msgs = [
    ("How do I complete my forms?", "support_question", "low"),
    ("Thank you for checking in!", "gratitude", "low"),
    ("What time is my appointment?", "confirmation_question", "low"),
    ("Will I be charged if I reschedule my appointment for today?", "support_question", "high"),
    ("Schedule", "schedule", "high"),
    ]
    anxiety_msgs = [
    ("I'm having pain, should I come in sooner?", "concern", "high"),
    ("I'm feeling very stressed about this visit.", "anxiety", "high"),
    ]

    # Choose based on current appointment outcome
    if status == "Cancelled":
        return random.choice(cancel_msgs + reschedule_msgs + anxiety_msgs)
    elif status == "Show":
        return random.choice(late_msgs + support_msgs + anxiety_msgs)
    elif status == "No-Show":
        return random.choice(cancel_msgs + reschedule_msgs + anxiety_msgs)
    else: # Scheduled / Future
        return random.choice(support_msgs + reschedule_msgs)

df_with_messages = df_full.sample(500).copy()

df_with_messages["patient_message"], df_with_messages["message_intent"], df_with_messages["stress_level"] = zip(
    *[generate_message_by_status(status) for status in df_with_messages["status"]]
)

# %%
df_with_messages.head(20)
# Out:
#                                  patient_id       patient_name  patient_age  \
# 5498   a109dbab-67ba-4a4d-bdf0-b75faca8e5a4      Nicole Thomas           24
# 6677   0b5a9b5a-ad28-470e-83d3-508ff20eda5a      Debbie Mccann           35
# 2753   8eed8d34-f384-4346-945f-4281236603b4     Kelly Anderson           29
# 2414   a747520f-e315-4b34-a2f5-63b1e8cdea8a      Angela Carter           32
# 8296   7ed7402f-8d9e-49b2-b864-28de4fbc3631        Karen Ellis           32
# 8121   17a86a12-14d2-405b-acf9-b230676f7928    Jocelyn Schultz           27
# 9700   82f9e879-3798-4443-a178-2c6cc5e18259    Danielle Flores           29
# 5833   86743542-6e7e-4484-a32b-df0d48b16c2a    Sara Washington           44
# 10104  7d6be102-88fb-4e9c-9813-7db6fbf2df25        Kayla Brown           36
# 2205   057eccfa-15f3-4747-90bb-5ed3c9765bdf      Shannon Brown           18
# 2245   27165ab6-73c1-4557-b6e2-6e93e62abbfe      Nicole Barnes           37
# 5440   a8747773-ed83-4ef6-b857-b817cb59575c        Tracy Duran           37
# 2319   7422acb0-a4d6-476c-a3f5-cc8d39cefff3    Melissa Mullins           22
# 5640   bde198a1-7170-44c9-acbc-1fa04ea5258f       Nicole Wiley           21
# 6902   00d0771a-1ab4-4b62-a37b-db3a656ba154        Mary Walter           33
# 500    6d39da75-aee7-4ab2-a1fa-8e7a078c26ce        Cindy Lopez           42
# 4211   4cc612f5-013e-4eb2-a2d2-95dbb27bd350  Allison Lopez DDS           37
# 8311   1f55f8ac-bd5d-4337-9e8c-22f2af4b354c      Sharon Thomas           33
# 3543   3157f09a-3edf-4ad0-8698-8643c14b2769  Elizabeth Sanchez           21
# 3040   4d9e4c77-0f79-4b76-9c96-703d5caf5c6a        Peggy Logan           23
#
#       zip_code        insurance    referral_source              visit_type  \
# 5498     36486  Major Insurance       DME Referred    New Patient Prenatal
# 6677     30572  Major Insurance  Provider Referred    New Patient Prenatal
# 2753     80058  Major Insurance  Provider Referred    New Patient Prenatal
# 2414     45100         Medicaid       DME Referred            Regular Care
# 8296     43281         Medicaid  Provider Referred            Regular Care
# 8121     64709  Major Insurance  Employer Referred            Regular Care
# 9700     32581  Major Insurance  Provider Referred            Regular Care
# 5833     71209  Major Insurance       DME Referred            Regular Care
# 10104    31587  Major Insurance  Provider Referred    New Patient Prenatal
# 2205     49747  Major Insurance  Provider Referred            Regular Care
# 2245     80051  Major Insurance  Provider Referred               Follow-up
# 5440     61699  Major Insurance       DME Referred            Regular Care
# 2319     40005         Medicaid  Provider Referred  New Patient Postpartum
# 5640     85246         Medicaid  Provider Referred               Follow-up
# 6902     13392  Major Insurance  Provider Referred            Regular Care
# 500      23147  Major Insurance       DME Referred               Follow-up
# 4211     12554  Major Insurance  Provider Referred            Regular Care
# 8311     86350  Major Insurance  Provider Referred  New Patient Postpartum
# 3543     37344  Major Insurance       DME Referred  New Patient Postpartum
# 3040     35619  Major Insurance  Provider Referred  New Patient Postpartum
#
#        booking_days_prior  confirmed_2_days_prior  ignored_all_outreach  \
# 5498                   20                    True                 False
# 6677                   19                    True                 False
# 2753                   17                   False                  True
# 2414                   30                   False                  True
# 8296                    6                    True                 False
# 8121                   18                   False                  True
# 9700                   27                    True                 False
# 5833                    6                    True                 False
# 10104                  24                    True                 False
# 2205                   16                    True                 False
# 2245                   30                    True                 False
# 5440                    6                    True                 False
# 2319                   27                   False                  True
# 5640                    1                   False                  True
# 6902                   18                    True                 False
# 500                    15                   False                  True
# 4211                   27                    True                 False
# 8311                   30                   False                  True
# 3543                   23                    True                 False
# 3040                    8                    True                 False
#
#        past_visits  past_no_shows  credit_card_on_file  baby_age_months  \
# 5498             2              0                False              NaN
# 6677             4              0                False              NaN
# 2753             0              1                False              NaN
# 2414             3              0                False              7.0
# 8296             5              0                 True              3.0
# 8121             1              0                False             14.0
# 9700             2              1                 True             12.0
# 5833             4              0                False             12.0
# 10104            3              0                False              NaN
# 2205             5              0                False              0.0
# 2245             3              0                False              NaN
# 5440             4              0                False              6.0
# 2319             4              0                 True              9.0
# 5640             5              0                False              NaN
# 6902             4              0                False              3.0
# 500              3              1                 True              NaN
# 4211             4              0                False             12.0
# 8311             5              0                 True              2.0
# 3543             4              1                False              7.0
# 3040             4              0                False             11.0
#
#           status                              patient_message  \
# 5498        Show                   Thank you for checking in!
# 6677        Show  I'm feeling very stressed about this visit.
# 2753     No-Show                           Why was I charged?
# 2414        Show                                     Schedule
# 8296        Show                   Thank you for checking in!
# 8121     No-Show                             I can't make it.
# 9700        Show                  How do I complete my forms?
# 5833        Show  I'm feeling very stressed about this visit.
# 10104  Scheduled                                           RS
# 2205        Show                                     Schedule
# 2245        Show          I'm going to be a few minutes late.
# 5440        Show                 What time is my appointment?
# 2319        Show          I'm going to be a few minutes late.
# 5640        Show                 What time is my appointment?
# 6902        Show          I'm having trouble joining the link
# 500         Show  I'm feeling very stressed about this visit.
# 4211        Show  I'm feeling very stressed about this visit.
# 8311        Show                  How do I complete my forms?
# 3543        Show                  How do I complete my forms?
# 3040        Show          I'm having trouble joining the link
#
#               message_intent stress_level
# 5498               gratitude          low
# 6677                 anxiety         high
# 2753      financial_question         high
# 2414                schedule         high
# 8296               gratitude          low
# 8121                  cancel       medium
# 9700        support_question          low
# 5833                 anxiety         high
# 10104     reschedule_request          low
# 2205                schedule         high
# 2245             late_notice          low
# 5440   confirmation_question          low
# 2319             late_notice          low
# 5640   confirmation_question          low
# 6902             late_notice         high
# 500                  anxiety         high
# 4211                 anxiety         high
# 8311        support_question          low
# 3543        support_question          low
# 3040             late_notice         high

# %% [markdown]
# ## <p style="color:hotpink"> **Merging Data**
#
# <p style="color:pink">We merge our communication sample back into the full dataset so only ~ 5% of patients have message data, simulating a realistic starting operational environment.

# %%
# Join back on patient_id so message data merges in
df_merged = df_full.merge(
    df_with_messages[["patient_id", "patient_message", "message_intent", "stress_level"]],
    on="patient_id",
    how="left" # keep all patients from df_full
)

# %%
# Check our new DF to ensure it is merged properly
df_merged.head(20)
# Out:
#                               patient_id         patient_name  patient_age  \
# 0   bdd640fb-0667-4ad1-9c80-317fa3b1799d       Courtney Doyle           32
# 1   16419f82-8b9d-4434-a465-e150bd9c66b3         Amanda Davis           21
# 2   8fadc1a6-06cb-4fb3-9a1d-e644815ef6d1        Marie Gardner           30
# 3   cf36d58b-4737-4190-96da-1dac72ff5d2a         Olivia Moore           23
# 4   371ecd7b-27cd-4130-8722-9389571aa876      Gabrielle Davis           32
# 5   9a8dca03-580d-4b71-98f5-64135be6128e       Amanda Stevens           19
# 6   142c3fe8-60e7-4113-ac1b-8ca1f91e1d4c    Sandra Montgomery           25
# 7   b45ed1f0-3139-432c-93cd-59bf5c941cf0           Mary Mejia           33
# 8   19db3ad0-ddd1-4fb2-bb98-2ef8daf61a26         Jody Flowers           19
# 9   ab9099a4-35a2-40ae-9af3-05535ec42e08          Taylor Wong           20
# 10  baa80dd4-88bd-4407-abcf-be01a28defe3         Julia Nelson           33
# 11  af42e12f-3838-4326-8e94-4239b02b61c4       Patricia Brown           18
# 12  448aaa9e-66b2-4c5b-90c1-87fcce177b4e        Susan Bradley           36
# 13  7fcd9eb1-a7ca-4415-b66e-b16f508ebad7        Suzanne Ellis           32
# 14  8fb5d27b-beb7-4919-bf22-faf823bed01d     Nicole Patterson           37
# 15  ff50bde4-3825-47b8-9cab-cc97663f1c97  Ms. Ann Williams MD           35
# 16  98ae4334-6c12-4ce8-ae34-0454cac5b68c         Jane Ferrell           36
# 17  dc5c0eed-8da0-465b-b898-97b9405cacec       Melanie Wilson           33
# 18  c4c2e2e3-444e-47c8-8039-87108976e334        Ashley Graham           21
# 19  e037e5ed-b8db-4672-b42d-47cc00d4af59         Valerie Gill           42
#
#    zip_code         insurance    referral_source              visit_type  \
# 0     95544   Major Insurance  Provider Referred  New Patient Postpartum
# 1     55477   Major Insurance  Provider Referred    New Patient Prenatal
# 2     32906   Major Insurance  Provider Referred    New Patient Prenatal
# 3     85866   Major Insurance  Provider Referred    New Patient Prenatal
# 4     70199   Major Insurance       DME Referred            Regular Care
# 5     63512   Major Insurance       DME Referred  New Patient Postpartum
# 6     36768   Major Insurance       DME Referred            Regular Care
# 7     35167   Major Insurance  Provider Referred            Regular Care
# 8     46334   Major Insurance       DME Referred            Regular Care
# 9     86248   Major Insurance  Provider Referred            Regular Care
# 10    73164   Major Insurance  Provider Referred  New Patient Postpartum
# 11    37075  Employer Insured       DME Referred  New Patient Postpartum
# 12    62941   Major Insurance  Provider Referred    New Patient Prenatal
# 13    23085   Major Insurance       DME Referred            Regular Care
# 14    65391   Major Insurance  Provider Referred               Follow-up
# 15    16311   Major Insurance  Provider Referred  New Patient Postpartum
# 16    28089   Major Insurance       DME Referred    New Patient Prenatal
# 17    36816   Major Insurance       DME Referred  New Patient Postpartum
# 18    46930   Major Insurance  Provider Referred            Regular Care
# 19    79661   Major Insurance       DME Referred  New Patient Postpartum
#
#     booking_days_prior  confirmed_2_days_prior  ignored_all_outreach  \
# 0                    1                   False                  True
# 1                   11                   False                  True
# 2                   17                   False                  True
# 3                    3                    True                 False
# 4                    0                   False                  True
# 5                   18                    True                 False
# 6                   15                    True                 False
# 7                    5                   False                  True
# 8                   12                    True                 False
# 9                   30                    True                 False
# 10                  24                    True                 False
# 11                  27                   False                  True
# 12                  23                    True                 False
# 13                  26                    True                 False
# 14                   5                   False                  True
# 15                  16                    True                 False
# 16                  21                    True                 False
# 17                   0                   False                  True
# 18                  14                    True                 False
# 19                  28                    True                 False
#
#     past_visits  past_no_shows  credit_card_on_file  baby_age_months  \
# 0             3              0                False             10.0
# 1             5              0                False              NaN
# 2             2              0                 True              NaN
# 3             0              0                 True              NaN
# 4             2              0                False              8.0
# 5             1              0                 True              9.0
# 6             2              0                False             11.0
# 7             2              0                 True             17.0
# 8             5              0                 True              1.0
# 9             2              0                False              3.0
# 10            3              0                 True              2.0
# 11            4              0                 True              8.0
# 12            4              0                False              NaN
# 13            3              0                 True             10.0
# 14            4              1                False              NaN
# 15            4              0                False             10.0
# 16            0              1                False              NaN
# 17            5              0                 True             12.0
# 18            1              0                False             15.0
# 19            2              1                 True              0.0
#
#        status                            patient_message message_intent  \
# 0        Show                                        NaN            NaN
# 1        Show                                        NaN            NaN
# 2        Show                                        NaN            NaN
# 3        Show                                        NaN            NaN
# 4   Cancelled                                        NaN            NaN
# 5        Show                                        NaN            NaN
# 6        Show                                        NaN            NaN
# 7        Show                                        NaN            NaN
# 8        Show                                        NaN            NaN
# 9        Show                                        NaN            NaN
# 10       Show                                        NaN            NaN
# 11       Show                                        NaN            NaN
# 12       Show                                        NaN            NaN
# 13       Show                                        NaN            NaN
# 14    No-Show                                        NaN            NaN
# 15       Show                                        NaN            NaN
# 16       Show                                        NaN            NaN
# 17       Show                                        NaN            NaN
# 18       Show  I'm having pain, should I come in sooner?        concern
# 19       Show                                        NaN            NaN
#
#    stress_level
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
# 14          NaN
# 15          NaN
# 16          NaN
# 17          NaN
# 18         high
# 19          NaN

# %% [markdown]
# ## <p style="color:hotpink"> **Saving Dataset**
#
# <p style="color:pink">Finally, save the final dataset as 'maternal_telehealth_full_dataset.csv' for downstream analysis and predictive modeling.

# %%
# Save dataset as a CSV
df_merged.to_csv("maternal_telehealth_full_dataset_final.csv", index=False)
